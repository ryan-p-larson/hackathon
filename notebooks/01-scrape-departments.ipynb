# %% [markdown]
# # Hackathon
#
# ## Scrape Departments
#
# Scrape departments for a list of URLs that point to classes for further scraping.

# %%
import requests
from bs4 import BeautifulSoup

# %%
class_urls = {
    "psych": "https://myui.uiowa.edu/my-ui/courses/by-department.page?q.academicUnitId=558&showResults=1",
    "bio": "https://myui.uiowa.edu/my-ui/courses/by-department.page?q.academicUnitId=537&showResults=1",
    "swahili": "https://myui.uiowa.edu/my-ui/courses/by-department.page?q.academicUnitId=674&showResults=1"
}

class_id = {
    "psych": 558,
    "bio": 537,
    "swahili": 674
}

# %% [markdown]
# **Explore the structure of the page.**
#
# 1. We need to see how each class is displayed within their cell
# 2. We need to paginate

# %%
def get_page_rows(soup):
    """
    """
    table = soup.find(id='search-result')
    table_body = table.find_next('tbody')
    table_rows = table_body.find_all('tr')
            
    return table_rows

# %%
def get_row_info(row):
    """
    """
    # each td has a separate piece of info
    cols = row.find_all('td')
    
    # but the top is the most important
    row_title = cols[0]
    
    # <a>, has multiple info for us
    row_a = row_title.find("a", { "class" : "text-underline" })
    course_name = row_a.text
    course_link = row_a.attrs['href']
    
    # Type of class
    try:
        course_type = row_title.find_next("em").text
    except:
        course_type = row.find_next("em").text
    
    return [course_name, course_link, course_type]

# %%
def scrape_department(url):
    """
    """
    # Request and check page
    page = requests.get(url)
    if (page.status_code != 200):
        print ("Couldn't request page, Err: {}".format(page.status_code))
        
    # Create soup for our functions
    soup = BeautifulSoup(page.content, 'html.parser')
    
    # get the raw rows from page
    rows = get_page_rows(soup)
    
    # format each row to get the class url and type
    rows_info = [get_row_info(row) for row in rows]
    
    # some pagination will have to go here but thats for later
    
    return rows_info

# %%
rows = scrape_department(class_urls['psych'])

# %%
class Scraper:
    def __init__(self):
        """
        """
        self.academicUnitID = None
        self.search_pages = []
        self.class_pages = []
        
    def create_search_page(self, page_num):
        """
        """
        search = "https://myui.uiowa.edu/my-ui/courses/by-department.page?page={}&q.academicUnitId={}&showResults=1".format(page_num, self.academicUnitID)
        return search
    
    def enqueue_search_page(self, url):
        """
        """
        self.search_pages.append(url)
    
    def get_search_pages(self, soup):
        """
        """
        
        # Every department has at least one class
        first_page = self.create_search_page(1)
        self.enqueue_search_page(first_page)
    
        # check if it has a pagination tag
        paging = soup.find("ul", {"class" : "pagination"})
        if (paging == None):
            # we're good!
            return
            
        # extract only the links
        page_links = paging.find_all('a')
        
        # These are the buttons
        for i in page_links:
            if ('title' in i.attrs):
                i_title = i.attrs['title']
                # only get buttons we need
                if (i_title.startswith('Go to page ')):
                    i_url = self.create_search_page(i.text)
                    self.enqueue_search_page(i_url)
        
        return
    

    def get_page_rows(self, soup):
        """
        """
        table = soup.find(id='search-result')
        table_body = table.find_next('tbody')
        table_rows = table_body.find_all('tr')

        return table_rows
    
    def get_row_info(self, row):
        """
        """
        # each td has a separate piece of info
        cols = row.find_all('td')

        # but the top is the most important
        row_title = cols[0]

        # <a>, has multiple info for us
        row_a = row_title.find("a", { "class" : "text-underline" })
        course_name = row_a.text
        course_link = 'https://myui.uiowa.edu' + row_a.attrs['href']

        # Type of class
        try:
            course_type = row_title.find_next("em").text
        except:
            course_type = row.find_next("em").text
            
        course_info = {
            'name': course_name,
            'link': course_link,
            'type': course_type
        }
        
        self.class_pages.append(course_info)

        return 
    
    def scrape_page(self, url):
        # Request and check page
        page = requests.get(url)
        if (page.status_code != 200):
            print ("Couldn't request page, Err: {}".format(page.status_code))

        # Create soup for our functions
        soup = BeautifulSoup(page.content, 'html.parser')

        # get the raw course rows from page
        rows = self.get_page_rows(soup)

        # format each row to get the class url and type
        for row in rows:
            # this will format and add it
            self.get_row_info(row)

        return 
        
    
    def start_scrape(self, academicUnitID):
        """
        """
        # set college
        self.academicUnitID = academicUnitID
        
        # Request and check page
        page_url = self.create_search_page(1)
        page = requests.get(page_url)
        
        if (page.status_code != 200):
            print ("Couldn't request page, Err: {}".format(page.status_code))

        # Create soup for our traversal
        soup = BeautifulSoup(page.content, 'html.parser')
        
        # Instantiate scraping queue
        self.get_search_pages(soup)
        
        # now that self has a list of pages
        for page in self.search_pages:
            # scrape each page
            self.scrape_page(page)
        
        
        return

# %%
scrape = Scraper()

# %%
scrape.start_scrape(class_id['psych'])

# %%
scrape.search_pages
# Out:
# ['https://myui.uiowa.edu/my-ui/courses/by-department.page?page=1&q.academicUnitId=558&showResults=1',
#  'https://myui.uiowa.edu/my-ui/courses/by-department.page?page=2&q.academicUnitId=558&showResults=1']

# %%
scrape.class_pages
# Out:
# [{'link': 'https://myui.uiowa.edu/my-ui/courses/details.page?_ticket=SfX5E-nyonxsYgY9Kg_1wyeYtXpT9Iue&id=831031&ci=147710',
#   'name': 'PSY:1001:0AAA',
#   'type': 'Lecture'},
#  {'link': 'https://myui.uiowa.edu/my-ui/courses/details.page?_ticket=ExMsVvBshZjqRM_fM6pCHlGWPxZB1Cdo&id=831032&ci=147710',
#   'name': 'PSY:1001:0A01',
#   'type': 'Discussion'},
#  {'link': 'https://myui.uiowa.edu/my-ui/courses/details.page?_ticket=uo_ZsjXillVYNus4BQt1QhTTpbfGzDeP&id=831033&ci=147710',
#   'name': 'PSY:1001:0A02',
#   'type': 'Discussion'},
#  {'link': 'https://myui.uiowa.edu/my-ui/courses/details.page?_ticket=veCJwyerdUtYNus4BQt1QieYtXpT9Iue&id=831034&ci=147710',
#   'name': 'PSY:1001:0A03',
#   'type': 'Discussion'},
#  {'link': 'https://myui.uiowa.edu/my-ui/courses/details.page?_ticket=7bmzdNQFqw_F5uOryZHTKlGWPxZB1Cdo&id=831035&ci=147710',
#   'name': 'PSY:1001:0A04',
#   'type': 'Discussion'},
#  {'link': 'https://myui.uiowa.edu/my-ui/courses/details.page?_ticket=ouFOu4a-7cjF5uOryZHTKvxrZxWWA5Tu&id=831036&ci=147710',
#   'name': 'PSY:1001:0A05',
#   'type': 'Discussion'},
#  {'link': 'https://myui.uiowa.edu/my-ui/courses/details.page?_ticket=71ezmw6GlD7F5uOryZHTKnAm4AbKQSK3&id=831037&ci=147710',
#   'name': 'PSY:1001:0A06',
#   'type': 'Discussion'},
#  {'link': 'https://myui.uiowa.edu/my-ui/courses/details.page?_ticket=nMPZ908NFR_0Ar9qSDyoARTTpbfGzDeP&id=831038&ci=147710',
#   'name': 'PSY:1001:0A07',
#   'type': 'Discussion'},
#  {'link': 'https://myui.uiowa.edu/my-ui/courses/details.page?_ticket=afMUocws61gwCwWE7rkwJhTTpbfGzDeP&id=831039&ci=147710',
#   'name': 'PSY:1001:0A08',
#   'type': 'Discussion'},
#  {'link': 'https://myui.uiowa.edu/my-ui/courses/details.page?_ticket=n3qXaDdWtv0wCwWE7rkwJieYtXpT9Iue&id=831040&ci=147710',
#   'name': 'PSY:1001:0A09',
#   'type': 'Discussion'},
#  {'link': 'https://myui.uiowa.edu/my-ui/courses/details.page?_ticket=Yr8LNfPNCzKHJrEWe9H04FGWPxZB1Cdo&id=831041&ci=147710',
#   'name': 'PSY:1001:0A10',
#   'type': 'Discussion'},
#  {'link': 'https://myui.uiowa.edu/my-ui/courses/details.page?_ticket=tHs3gHsilAqHJrEWe9H04PxrZxWWA5Tu&id=831042&ci=147710',
#   'name': 'PSY:1001:0A11',
#   'type': 'Discussion'},
#  {'link': 'https://myui.uiowa.edu/my-ui/courses/details.page?_ticket=OWJ94385qQSHJrEWe9H04HAm4AbKQSK3&id=831043&ci=147710',
#   'name': 'PSY:1001:0A12',
#   'type': 'Discussion'},
#  {'link': 'https://myui.uiowa.edu/my-ui/courses/details.page?_ticket=fvAFYhSsDt-kjl_tdtFdWhTTpbfGzDeP&id=831044&ci=147710',
#   'name': 'PSY:1001:0A13',
#   'type': 'Discussion'},
#  {'link': 'https://myui.uiowa.edu/my-ui/courses/details.page?_ticket
0001',
#   'type': 'This course has specific requirements'},
#  {'link': 'https://myui.uiowa.edu/my-ui/courses/details.page?_ticket=qYlKo8VK4DnSs2EkLMxz0mlIsIVeWhWC&id=835438&ci=156493',
#   'name': 'PSY:6370:0001',
#   'type': 'This course has specific requirements'},
#  {'link': 'https://myui.uiowa.edu/my-ui/courses/details.page?_ticket=AKEcHPZE_KHSs2EkLMxz0rXZMu7NiOk4&id=841259&ci=169814',
#   'name': 'PSY:6590:0001',
#   'type': 'This course has specific requirements'},
#  {'link': 'https://myui.uiowa.edu/my-ui/courses/details.page?_ticket=xiv5mF_OQ4OiR_V-A9C5O6sYcJDpnriZ&id=836255&ci=169363',
#   'name': 'PSY:7070:0001',
#   'type': 'This course has specific requirements'},
#  {'link': 'https://myui.uiowa.edu/my-ui/courses/details.page?_ticket=ilTWjM9MIb2iR_V-A9C5O7gdciy0mWMU&id=835525&ci=168341',
#   'name': 'PSY:7090:0001',
#   'type': 'This course has specific requirements'},
#  {'link': 'https://myui.uiowa.edu/my-ui/courses/details.page?_ticket=NrrOMHnon1Oqwo0PCOY-FOXViknJMnWG&id=831109&ci=147757',
#   'name': 'PSY:7110:0IND',
#   'type': 'Independent Study'},
#  {'link': 'https://myui.uiowa.edu/my-ui/courses/details.page?_ticket=jay6r8HZlnuqwo0PCOY-FC58yI4ejB20&id=831107&ci=147755',
#   'name': 'PSY:7120:0IND',
#   'type': 'Independent Study'},
#  {'link': 'https://myui.uiowa.edu/my-ui/courses/details.page?_ticket=-uWTOqyAeSOqwo0PCOY-FLXZMu7NiOk4&id=831108&ci=147756',
#   'name': 'PSY:7130:0IND',
#   'type': 'Independent Study'},
#  {'link': 'https://myui.uiowa.edu/my-ui/courses/details.page?_ticket=bvAMH3yx8yleQWHP61c4I2lIsIVeWhWC&id=841257&ci=153032',
#   'name': 'PSY:7150:0001',
#   'type': 'Analyzing Neural Field Potentials: Electroencephalography, Electrocorticography, and Local Field Potentials'},
#  {'link': 'https://myui.uiowa.edu/my-ui/courses/details.page?_ticket=60fx5XVD4lleQWHP61c4I7gdciy0mWMU&id=831106&ci=147754',
#   'name': 'PSY:7160:0IND',
#   'type': 'Independent Study'},
#  {'link': 'https://myui.uiowa.edu/my-ui/courses/details.page?_ticket=te7EIhLbMbheQWHP61c4Iy_NcRa8iJ4V&id=835535&ci=168929',
#   'name': 'PSY:7170:0IND',
#   'type': 'Independent Study'},
#  {'link': 'https://myui.uiowa.edu/my-ui/courses/details.page?_ticket=jZ1F6ftvE5MsluaIYMqRHJnQkzT3pdi7&id=833898&ci=150808',
#   'name': 'PSY:7310:0001',
#   'type': 'This course has specific requirements'},
#  {'link': 'https://myui.uiowa.edu/my-ui/courses/details.page?_ticket=mIyfy2b85eYsluaIYMqRHDCtfNMxRz94&id=831111&ci=147760',
#   'name': 'PSY:7350:0001',
#   'type': 'This course has specific requirements'},
#  {'link': 'https://myui.uiowa.edu/my-ui/courses/details.page?_ticket=nc30hUKa8EYWpjkbOMudE6sYcJDpnriZ&id=831112&ci=147761',
#   'name': 'PSY:7355:0001',
#   'type': 'This course has specific requirements'},
#  {'link': 'https://myui.uiowa.edu/my-ui/courses/details.page?_ticket=mq9_yKbPqPUWpjkbOMudE7gdciy0mWMU&id=831110&ci=147762',
#   'name': 'PSY:7360:0001',
#   'type': 'This course has specific requirements'},
#  {'link': 'https://myui.uiowa.edu/my-ui/courses/details.page?_ticket=7vv87b9MRS8DJ_om3PLTWmlIsIVeWhWC&id=832507&ci=150500',
#   'name': 'PSY:7365:0001',
#   'type': 'This course has specific requirements'},
#  {'link': 'https://myui.uiowa.edu/my-ui/courses/details.page?_ticket=O_ZzONIuBRoDJ_om3PLTWnpdHXxZWaha&id=833710&ci=158187',
#   'name': 'PSY:7370:0001',
#   'type': 'This course has specific requirements'},
#  {'link': 'https://myui.uiowa.edu/my-ui/courses/details.page?_ticket=nJpSEoaFJX0DJ_om3PLTWrXZMu7NiOk4&id=835159&ci=151505',
#   'name': 'PSY:7510:0001',
#   'type': 'This course has specific requirements'},
#  {'link': 'https://myui.uiowa.edu/my-ui/courses/details.page?_ticket=7fGKCYVhsf-swNdJgr0zhpnQkzT3pdi7&id=838172&ci=170473',
#   'name': 'PSY:7604:0001',
#   'type': 'This course has specific requirements'},
#  {'link': 'https://myui.uiowa.edu/my-ui/courses/details.page?_ticket=6XnfBZqDPQSswNdJgr0zhjCtfNMxRz94&id=841260&ci=150641',
#   'name': 'PSY:7610:0001',
#   'type': 'Eye Movements in Cognition'},
#  {'link': 'https://myui.uiowa.edu/my-ui/courses/details.page?_ticket=vF_CHLk8RNyLu790bbJSJmlIsIVeWhWC&id=838173&ci=170475',
#   'name': 'PSY:7620:0001',
#   'type': 'This course has specific requirements'}]

# %%
swahili_scrape = Scraper()
swahili_scrape.start_scrape(674)

# %%
swahili_scrape.search_pages
# Out:
# ['https://myui.uiowa.edu/my-ui/courses/by-department.page?page=1&q.academicUnitId=674&showResults=1']

# %%
swahili_scrape.class_pages
# Out:
# []
