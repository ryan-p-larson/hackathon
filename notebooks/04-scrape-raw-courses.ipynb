# %% [markdown]
# # Automating Departments

# %%
# %run ../src/DepartmentScraper.py
# %run ../src/CourseScraper.py

# %%
import pandas as pd
from multiprocessing import Pool
from os import listdir

# %%
num_cores = 4
base_f = '../data/courses/'

departments = pd.read_csv('../data/departments.csv')
departments.head()
# Out:
#                                 college  \
# 0  College of Liberal Arts and Sciences
# 1  College of Liberal Arts and Sciences
# 2  College of Liberal Arts and Sciences
# 3  College of Liberal Arts and Sciences
# 4  College of Liberal Arts and Sciences
#
#                                           department  \
# 0  College of Liberal Arts and Sciences Non-depar...
# 1                           African American Studies
# 2         American Indian and Native Studies Program
# 3                                   American Studies
# 4                                       Anthropology
#
#                                                 href
# 0  https://myui.uiowa.edu/my-ui/courses/by-depart...
# 1  https://myui.uiowa.edu/my-ui/courses/by-depart...
# 2  https://myui.uiowa.edu/my-ui/courses/by-depart...
# 3  https://myui.uiowa.edu/my-ui/courses/by-depart...
# 4  https://myui.uiowa.edu/my-ui/courses/by-depart...

# %%
list_colleges = ['College of Liberal Arts and Sciences', 'Tippie College of Business', 'College of Engineering',
 'University College', 'College of Education']

to_scrape = lambda x: x in list_colleges

colleges_to_scrape = departments[departments['college'].apply(to_scrape) == True]

# %% [markdown]
# ---
#
# **Example**

# %%
department_scraper = DepartmentScraper()

#for i in departments.loc[1]['href']:
    #department_scraper.start_scrape(i)
department_scraper.start_scrape(departments.loc[1]['href'])

# %%
course_scraper = CourseScraper(department_scraper.class_pages)

# %%
df = course_scraper.courses_df

print (df.columns)
df.head()

# %%
f_out = '../data/raw-courses.json'
df.to_json(f_out, orient='records', lines=True)

# %% [markdown]
# **For Real**

# %%
for college in list_colleges:
    
    print ("Starting {} Departments.".format(college))
    college_deps = departments[departments['college'] == college]
    
    for dep in college_deps.to_records():
        try:        
            dep_name = dep[2].lower().replace('&', '').replace("'", "").replace(' ', '-')
            dep_file = base_f + dep_name + '.json'
            dep_link = dep[3]

            #print (dep_name, dep_link, dep_file)

            dep_scraper = DepartmentScraper()
            print ("\tScraping {} classes".format(dep_name))
            dep_scraper.start_scrape(dep_link)

            print ("\tDone scraping classes. extracting now")
            dep_courses = CourseScraper(dep_scraper.class_pages)
            dep_courses.courses_df.to_json(dep_file, orient='records', lines=True)
        except Exception as e:
            print (e, dep)

# %%
for college in list_colleges:
    print ("Starting {} Departments.".format(college))
    college_deps = departments[departments['college'] == college]
    
    college_deps.apply(lambda x: process_department(x), axis=1)
# Out:
# Starting College of Liberal Arts and Sciences Departments.
# 	Scraping college-of-liberal-arts-and-sciences-non-departmental-courses classes
# 'NoneType' object has no attribute 'text' college                    College of Liberal Arts and Sciences
# department    College of Liberal Arts and Sciences Non-depar...
# href          https://myui.uiowa.edu/my-ui/courses/by-depart...
# Name: 0, dtype: object
# 	Skipping african-american-studies
# 	Skipping american-indian-and-native-studies-program
# 	Skipping american-studies
# 	Skipping anthropology
# 	Skipping arabic-language-and-literature
# 	Skipping school-of-art-and-art-history
# 	Skipping asian--slavic-languages-and-literatures
# 	Skipping american-sign-language
# 	Skipping aging-and-longevity-studies-program
# 	Skipping biology
# 	Skipping critical-cultural-competence-certificate-program
# 	Skipping cinematic-arts
# 	Skipping chemistry
# 	Skipping clas-non-departmental
# 	Skipping classics
# 	Skipping communication-studies
# 	Skipping computer-science
# 	Skipping creative-writing-writers-workshop
# 	Skipping dance
# 	Skipping division-of-world-languages,-literatures-and-cultures
# 	Skipping english
# 	Skipping environmental-sciences
# 	Skipping english-as-a-second-language-programs
# 	Skipping french-and-italian
# 	Scraping general-education-literature classes
# 'NoneType' object has no attribute 'text' college                    College of Liberal Arts and Sciences
# department                         General Education Literature
# href          https://myui.uiowa.edu/my-ui/courses/by-depart...
# Name: 25, dtype: object
# 	Skipping geographical-and-sustainability-sciences
# 	Skipping earth-and-environmental-sciences
# 	Skipping global-health-studies
# 	Skipping german
# 	Skipping history
# 	Skipping health-and-physical-activity-skills
# 	Skipping interdepartmental-studies
# 	Scraping division-of-interdisciplinary-programs classes
# 'NoneType' object has no attribute 'text' college                    College of Liberal Arts and Sciences
# department               Division of Interdisciplinary Programs
# href          https://myui.uiowa.edu/my-ui/courses/by-depart...
# Name: 33, dtype: object
# 	Skipping health-and-human-physiology
# 	Skipping international-studies
# 	Scraping iowa-young-writers-studio classes
# 'NoneType' object has no attribute 'text' college                    College of Liberal Arts and Sciences
# department                           Iowa Young Writers' Studio
# href          https://myui.uiowa.edu/my-ui/courses/by-depart...
# Name: 36, dtype: object
# 	Skipping school-of-journalism-and-mass-communication
# 	Skipping latin-american-studies
# 	Scraping latina/o-studies classes
# 	Done scraping classes. extracting now
# 	 Scraping course pages...
# 		0/4  LATS:1700:0001...
# 		1/4  LATS:2050:0001...
# 		2/4  LATS:2280:0001...
# 		3/4  LATS:4800:0001...
# [Errno 2] No such file or directory: '../data/courses/latina/o-studies.json' college                    College of Liberal Arts and Sciences
# department                                     Latina/o Studies
# href          https://myui.uiowa.edu/my-ui/courses/by-depart...
# Name: 39, dtype: object
# 	Skipping linguistics
# 	Skipping mathematics
# 	Skipping medieval-studies-program
# 	Skipping school-of-music
# 	Skipping museum-studies
# 	Skipping optical-science-and-technology-center
# 	Skipping performing-arts-entrepreneurship
# 	Skipping philosophy
# 	Skipping physics-and-astronomy
# 	Skipping political-science
# 	Skipping psychological-and-brain-sciences
# 	Skipping religious-studies
# 	Skipping rhetoric
# 	Skipping second-language-acquisition
# 	Skipping russian
# 	Skipping sociology
# 	Skipping communication-sciences-and-disorders
# 	Skipping spanish-and-portuguese
# 	Skipping sport-studies
# 	Skipping school-of-social-work
# 	Skipping statistics-and-actuarial-science
# 	Skipping swahili
# 	Skipping theatre-arts
# 	Skipping gender,-womens,-and-sexuality-studies
# 	Skipping magid-center-for-undergraduate-writing
# Starting Tippie College of Business Departments.
# 	Scraping tippie-college-of-business-non-departmental-courses classes
# 'NoneType' object has no attribute 'text' college                              Tippie College of Business
# department    Tippie College of Business Non-departmental Co...
# href          https://myui.uiowa.edu/my-ui/courses/by-depart...
# Name: 65, dtype: object
# 	Scraping accounting classes
# 	Done scraping classes. extracting now
# 	 Scraping course pages...
# 		0/81  ACCT:1300:0001...
# 		1/81  ACCT:1300:0002...
# 		2/81  ACCT:2100:0001...
# 		3/81  ACCT:2100:0002...
# 		4/81  ACCT:2100:0003...
# 		5/81  ACCT:2100:0004...
# 		6/81  ACCT:2100:0005...
# 		7/81  ACCT:2100:0006...
# 		8/81  ACCT:2100:0007...
# 		9/81  ACCT:2100:0008...
# 		10/81  ACCT:2100:0009...
# 		11/81  ACCT:2100:0010...
# 		12/81  ACCT:2100:0011...
# 		13/81  ACCT:2100:0012...
# 		14/81  ACCT:2100:0013...
# 		15/81  ACCT:2100:0014...
# 		16/81  ACCT:2100:0015...
# 		17/81  ACCT:2100:0016...
# 		18/81  ACCT:2100:0017...
# 		19/81  ACCT:2100:0018...
# 		20/81  ACCT:2100:0019...
# 		21/81  ACCT:2100:0020...
# 		22/81  ACCT:2100:0021...
# 		23/81  ACCT:2100:0EXV...
# 		24/81  ACCT:2100:0EXW...
# 		25/81  ACCT:2200:0001...
# 		26/81  ACCT:2200:0002...
# 		27/81  ACCT:2200:0003...
# 		28/81  ACCT:2200:0004...
# 		29/81  ACCT:2200:0005...
# 		30/81  ACCT:2200:0006...
# 		31/81  ACCT:2200:0007...
# 		32/81  ACCT:2200:0008...
# 		33/81  ACCT:2200:0009...
# 		34/81  ACCT:2200:0010...
# 		35/81  ACCT:2200:0011...
# 		36/81  ACCT:2200:0012...
# 		37/81  ACCT:2200:0EX4...
# 		38/81  ACCT:2200:0EXV...
# 		39/81  ACCT:2200:0EXW...
# 		40/81  ACCT:3020:0001...
# 		41/81  ACCT:3020:0002...
# 		42/81  ACCT:3100:0001...
# 		43/81  ACCT:3200:0AAA...
# 		44/81  ACCT:3200:0A01...
# 		45/81  ACCT:3200:0BBB...
# 		46/81  ACCT:3200:0B02...
# 		47/81  ACCT:3200:0CCC...
# 		48/81  ACCT:3200:0C03...
# 		49/81  ACCT:3200:0EX4...
# 		50/81  ACCT:3300:0AAA...
# 		51/81  ACCT:3300:0A01...
# 		52/81  ACCT:3300:0BBB...
# 		53/81  ACCT:3300:0B10...
# 		54/81  ACCT:3400:0AAA...
# 		55/81  ACCT:3400:0A01...
# 		56/81  ACCT:3400:0BBB...
# 		57/81  ACCT:3400:0B01...
# 		58/81  ACCT:3450:0001...
# 		59/81  ACCT:3450:0002...
# 		60/81  ACCT:3500:0001...
# 		61/81  ACCT:3500:0002...
# 		62/81  ACCT:3500:0003...
# 		63/81  ACCT:3600:0001...
# 		64/81  ACCT:4050:0001...
# 		65/81  ACCT:4100:0001...
# 		66/81  ACCT:4100:0002...
# 		67/81  ACCT:4200:0001...
# 		68/81  ACCT:4200:0002...
# 		69/81  ACCT:4300:0001...
# 		70/81  ACCT:4900:0001...
# 		71/81  ACCT:4999:0IND...
# 		72/81  ACCT:7850:0001...
# 		73/81  ACCT:7900:0001...
# 		74/81  ACCT:7975:0IND...
# 		75/81  ACCT:9020:0001...
# 		76/81  ACCT:9020:0900...
# 		77/81  ACCT:9020:0EX8...
# 		78/81  ACCT:9120:0001...
# 		79/81  ACCT:9130:0001...
# 		80/81  ACCT:9130:0002...
# 	Skipping business-administration
# 	Skipping economics
# 	Skipping entrepreneurship
# 	Scraping executive-mba-program classes
# 'NoneType' object has no attribute 'text' college                              Tippie College of Business
# department                                Executive MBA Program
# href          https://myui.uiowa.edu/my-ui/courses/by-depart...
# Name: 70, dtype: object
# 	Skipping finance
# 	Scraping international-executive-program classes
# 'NoneType' object has no attribute 'text' college                              Tippie College of Business
# department                      International Executive Program
# href          https://myui.uiowa.edu/my-ui/courses/by-depart...
# Name: 72, dtype: object
# 	Skipping mba-program
# 	Scraping mba-professional-program classes
# 'NoneType' object has no attribute 'text' college                              Tippie College of Business
# department                             MBA Professional Program
# href          https://myui.uiowa.edu/my-ui/courses/by-depart...
# Name: 74, dtype: object
# 	Skipping management-and-organizations
# 	Skipping marketing
# 	Skipping management-sciences
# Starting College of Engineering Departments.
# 	Skipping college-of-engineering-non-departmental-courses
# 	Skipping biomedical-engineering
# 	Skipping chemical-and-biochemical-engineering
# 	Skipping civil-and-environmental-engineering
# 	Skipping electrical-and-computer-engineering
# 	Skipping mechanical-and-industrial-engineering
# Starting University College Departments.
# 	Scraping university-college-non-departmental-courses classes
# 'NoneType' object has no attribute 'text' college                                      University College
# department          University College Non-departmental Courses
# href          https://myui.uiowa.edu/my-ui/courses/by-depart...
# Name: 164, dtype: object
# 	Skipping study-abroad
# 	Skipping aerospace-studies
# 	Scraping agep-summer-program classes
# 'NoneType' object has no attribute 'text' college                                      University College
# department                                  AGEP Summer Program
# href          https://myui.uiowa.edu/my-ui/courses/by-depart...
# Name: 167, dtype: object
# 	Skipping belin-blank-center-for-gifted-education
# 	Skipping career-center-programs
# 	Scraping center-for-diversity-and-enrichment classes
# 'NoneType' object has no attribute 'text' college                                      University College
# department                  Center for Diversity and Enrichment
# href          https://myui.uiowa.edu/my-ui/courses/by-depart...
# Name: 170, dtype: object
# 	Skipping college-success-initiatives
# 	Scraping first-year-programs classes
# 'NoneType' object has no attribute 'text' college                                      University College
# department                                  First-Year Programs
# href          https://myui.uiowa.edu/my-ui/courses/by-depart...
# Name: 172, dtype: object
# 	Scraping intercollegiate-athletic-participation classes
# 'NoneType' object has no attribute 'text' college                                      University College
# department               Intercollegiate Athletic Participation
# href          https://myui.uiowa.edu/my-ui/courses/by-depart...
# Name: 173, dtype: object
# 	Skipping iowa-biosciences-academy
# 	Scraping international-programs classes
# 'NoneType' object has no attribute 'text' college                                      University College
# department                               International Programs
# href          https://myui.uiowa.edu/my-ui/courses/by-depart...
# Name: 175, dtype: object
# 	Skipping lifetime-leisure-skills
# 	Skipping leadership-studies
# 	Skipping military-science
# 	Scraping orientation-training classes
# 'NoneType' object has no attribute 'text' college                                      University College
# department                                 Orientation Training
# href          https://myui.uiowa.edu/my-ui/courses/by-depart...
# Name: 179, dtype: object
# 	Scraping patient-care-practicum classes
# 'NoneType' object has no attribute 'text' college                                      University College
# department                               Patient Care Practicum
# href          https://myui.uiowa.edu/my-ui/courses/by-depart...
# Name: 180, dtype: object
# 	Skipping biomedical-and-health-sciences
# 	Scraping research-experiences-for-undergraduates-in-microbiology classes
# 'NoneType' object has no attribute 'text' college                                      University College
# department    Research Experiences for Undergraduates in Mic...
# href          https://myui.uiowa.edu/my-ui/courses/by-depart...
# Name: 182, dtype: object
# 	Scraping student-information-technology-skills classes
# 'NoneType' object has no attribute 'text' college                                      University College
# department                Student Information Technology Skills
# href          https://myui.uiowa.edu/my-ui/courses/by-depart...
# Name: 183, dtype: object
# 	Scraping summer-medical-scientist-training-program classes
# 'NoneType' object has no attribute 'text' college                                      University College
# department            Summer Medical Scientist Training Program
# href          https://myui.uiowa.edu/my-ui/courses/by-depart...
# Name: 184, dtype: object
# 	Scraping secondary-student-training-program classes
# 'NoneType' object has no attribute 'text' college                                      University College
# department                   Secondary Student Training Program
# href          https://myui.uiowa.edu/my-ui/courses/by-depart...
# Name: 185, dtype: object
# 	Scraping student-services classes
# 'NoneType' object has no attribute 'text' college                                      University College
# department                                     Student Services
# href          https://myui.uiowa.edu/my-ui/courses/by-depart...
# Name: 186, dtype: object
# 	Skipping university-of-iowa-honors-program
# 	Scraping iowa-lakeside-laboratory classes
# 'NoneType' object has no attribute 'text' college                                      University College
# department                             Iowa Lakeside Laboratory
# href          https://myui.uiowa.edu/my-ui/courses/by-depart...
# Name: 188, dtype: object
# 	Scraping university-of-iowa-upward-bound classes
# 'NoneType' object has no attribute 'text' college                                      University College
# department                      University of Iowa Upward Bound
# href          https://myui.uiowa.edu/my-ui/courses/by-depart...
# Name: 189, dtype: object
# 	Skipping university-libraries
# 	Skipping undergraduate-research-experiences
# Starting College of Education Departments.
# 	Skipping college-of-education-non-departmental-courses
# 	Skipping rehabilitation-and-counselor-education
# 	Skipping education-interdepartmental
# 	Skipping teaching-and-learning
# 	Skipping educational-policy-and-leadership-studies
# 	Skipping psychological-and-quantitative-foundations
# 	Skipping ui-reach-program

# %%
def process_department(dep):
    #dep = departments[departments['department'] == department].to_records()[0]
    
    try:        
        dep_name = dep['department'].lower().replace('&', '').replace("'", "").replace("/", "").replace(' ', '-')
        dep_file = base_f + dep_name + '.json'
        dep_link = dep['href']
        #print (dep_name, dep_link, dep_file)
        
        # sanity check
        if dep_file.split('/')[-1] not in listdir(base_f):
            dep_scraper = DepartmentScraper()
            print ("\tScraping {} classes".format(dep_name))
            dep_scraper.start_scrape(dep_link)

            print ("\tDone scraping classes. extracting now")
            dep_courses = CourseScraper(dep_scraper.class_pages)
            dep_courses.courses_df.to_json(dep_file, orient='records', lines=True)
        else:
            print ("\tSkipping {}".format(dep_name))
    except Exception as e:
        print (e, dep)
