# %% [markdown]
# # Automating Departments

# %%
# %run ../src/DepartmentScraper.py
# %run ../src/CourseScraper.py

# %%
import pandas as pd

# %%
departments = pd.read_csv('../data/departments.csv')
departments.head()
# Out:
#                                 college  \
# 0  College of Liberal Arts and Sciences
# 1  College of Liberal Arts and Sciences
# 2  College of Liberal Arts and Sciences
# 3  College of Liberal Arts and Sciences
# 4  College of Liberal Arts and Sciences
#
#                                           department  \
# 0  College of Liberal Arts and Sciences Non-depar...
# 1                           African American Studies
# 2         American Indian and Native Studies Program
# 3                                   American Studies
# 4                                       Anthropology
#
#                                                 href
# 0  https://myui.uiowa.edu/my-ui/courses/by-depart...
# 1  https://myui.uiowa.edu/my-ui/courses/by-depart...
# 2  https://myui.uiowa.edu/my-ui/courses/by-depart...
# 3  https://myui.uiowa.edu/my-ui/courses/by-depart...
# 4  https://myui.uiowa.edu/my-ui/courses/by-depart...

# %%
department_scraper = DepartmentScraper()

#for i in departments.loc[1]['href']:
    #department_scraper.start_scrape(i)
department_scraper.start_scrape(departments.loc[1]['href'])

# %%
#department_scraper.class_pages

# %%
course_scraper = CourseScraper(department_scraper.class_pages)
# Out:
# Scraping course pages...
# 0/15AFAM:1020:0001...
# 1/15AFAM:1030:0001...
# 2/15AFAM:2070:0BBB...
# 3/15AFAM:2070:0B01...
# 4/15AFAM:2070:0B02...
# 5/15AFAM:2070:0B03...
# 6/15AFAM:2079:0001...
# 7/15AFAM:2465:0001...
# 8/15AFAM:2500:0001...
# 9/15AFAM:2500:0EXW...
# 10/15AFAM:2800:0001...
# 11/15AFAM:3275:0001...
# 12/15AFAM:3459:0001...
# 13/15AFAM:3925:0001...
# 14/15AFAM:4310:0001...

# %%
df = course_scraper.courses_df

print (df.columns)
df.head()
# Out:
# Index(['Applicable Fees', 'Approved GE', 'Co-Existing Sections',
#        'Corequisites', 'Course', 'Cross References', 'Delivery Modes',
#        'Department', 'Description', 'General Catalog', 'Instructors', 'Link',
#        'Management Type', 'Minimum Fee Hours', 'Name', 'Prerequisites',
#        'Recommendations', 'Repeatable', 'Requirements', 'Restrictions',
#        'Special Grading Instructions', 'Textbooks and Resources',
#        'Time and Location', 'Type'],
#       dtype='object')
#   Applicable Fees                                        Approved GE  \
# 0            None  Students admitted Summer 2017 or after\n\nValu...
# 1            None  Students admitted Summer 2017 or after\n\nSoci...
# 2            None                                               None
# 3            None                                               None
# 4            None                                               None
#
#   Co-Existing Sections Corequisites          Course Cross References  \
# 0                 None         None  AFAM:1020:0001   AMST:1030:0001
# 1                 None         None  AFAM:1030:0001             None
# 2                 None         None  AFAM:2070:0BBB   COMM:2069:0BBB
# 3                 None         None  AFAM:2070:0B01   COMM:2069:0B01
# 4                 None         None  AFAM:2070:0B02   COMM:2069:0B02
#
#   Delivery Modes                                         Department  \
# 0            NaN  College of Liberal Arts and Sciences\n        ...
# 1            NaN  College of Liberal Arts and Sciences\n        ...
# 2            NaN  College of Liberal Arts and Sciences\n        ...
# 3            NaN  College of Liberal Arts and Sciences\n        ...
# 4            NaN  College of Liberal Arts and Sciences\n        ...
#
#                                          Description  \
# 0  This course is designed to introduce students ...
# 1  Students are encouraged to use critical thinki...
# 2  This course examines the social and political ...
# 3  This course examines the social and political ...
# 4  This course examines the social and political ...
#
#                                      General Catalog     ...      \
# 0  Interdisciplinary look at Black culture in the...     ...
# 1  Social and cultural history of African America...     ...
# 2  Social and political impact of television dram...     ...
# 3  Social and political impact of television dram...     ...
# 4  Social and political impact of television dram...     ...
#
#                                                 Name  \
# 0  AFAM:1020:0001 Introduction to African America...
# 1  AFAM:1030:0001 Introduction to African America...
# 2            AFAM:2070:0BBB Black TV Drama: The Wire
# 3            AFAM:2070:0B01 Black TV Drama: The Wire
# 4            AFAM:2070:0B02 Black TV Drama: The Wire
#
#                                        Prerequisites Recommendations  \
# 0  None\n                \n                    \n...            None
# 1  None\n                \n                    \n...            None
# 2  None\n                \n                    \n...            None
# 3  None\n                \n                    \n...            None
# 4  None\n                \n                    \n...            None
#
#   Repeatable Requirements Restrictions Special Grading Instructions  \
# 0         No         None         None                         None
# 1         No         None         None                         None
# 2         No         None         None                         None
# 3         No         None         None                         None
# 4         No         None         None                         None
#
#                              Textbooks and Resources  \
# 0      Required Textbooks/materials not yet reported
# 1  The following textbook and resource informatio...
# 2                              No textbooks required
# 3                              No textbooks required
# 4                              No textbooks required
#
#                                    Time and Location        Type
# 0  Start and end times: \n2:00P - 3:15P\nTTh\n203...     Lecture
# 1  Start and end times: \n11:00A - 12:15P\nTTh\n2...     Lecture
# 2  Start and end times: \n12:30P - 1:20P\nMW\n301...     Lecture
# 3  Start and end times: \n2:00P - 2:50P\nTh\n8\n\...  Discussion
# 4  Start and end times: \n12:30P - 1:20P\nF\n208\...  Discussion
#
# [5 rows x 24 columns]

# %%
# create lookup table for lecture hours
discussions = df[df['Type'] == 'Discussion']

discussion_hrs = {}
def map_discussion(x):
    course = x['Course']
    course_clean = ":".join(course.split(':')[:2])
    hrs = x['Minimum Fee Hours']
    
    discussion_hrs[course_clean] = hrs
    
discussions.apply(lambda x: map_discussion(x), axis=1)

# check output
discussion_hrs

# %%
discussion_hrs
