# %% [markdown]
# # Combine and Format Courses

# %%
import pandas as pd
from os import listdir

# %%
raw_classes = listdir('../data/courses/')
combined_classes = pd.concat([pd.read_json('../data/courses/'+i, lines=True) for i in raw_classes])

# %%
combined_classes.to_json('../data/raw-courses.json', orient='records')

# %%
print (combined_classes.columns)
combined_classes.head()
# Out:
# Index(['Applicable Fees', 'Approved GE', 'Co-Existing Sections',
#        'Corequisites', 'Course', 'Cross References', 'Delivery Modes',
#        'Delivery Tools', 'Department', 'Description', 'General Catalog',
#        'Instructors', 'Link', 'Management Type', 'Midterm Exam(s)',
#        'Minimum Fee Hours', 'Name', 'Prerequisites', 'Professional Exam(s)',
#        'Recommendations', 'Registration Information', 'Repeatable',
#        'Requirements', 'Restrictions', 'Screenings', 'Seat Reservations',
#        'Special Grading Instructions', 'Textbooks and Resources',
#        'Time and Location', 'Type', 'courseID', 'college', 'department',
#        'course_num', 'name', 'prereqs', 'hrs'],
#       dtype='object')
#   Applicable Fees                                        Approved GE  \
# 0            None                                               None
# 1            None                                               None
# 2            None                                               None
# 3            None  Students admitted Summer 2017 or after\n\nValu...
# 4            None  Students admitted Summer 2017 or after\n\nValu...
#
#   Co-Existing Sections Corequisites          Course Cross References  \
# 0                 None         None  EPLS:3000:0001             None
# 1                 None         None  EPLS:3000:0002             None
# 2                 None         None  EPLS:3000:0003             None
# 3                 None         None  EPLS:4180:0AAA             None
# 4                 None         None  EPLS:4180:0A02             None
#
#   Delivery Modes Delivery Tools  \
# 0           None           None
# 1           None           None
# 2           None           None
# 3           None           None
# 4           None           None
#
#                                           Department  \
# 0  College of Education\n                \n      ...
# 1  College of Education\n                \n      ...
# 2  College of Education\n                \n      ...
# 3  College of Education\n                \n      ...
# 4  College of Education\n                \n      ...
#
#                                          Description ...   \
# 0  This course offers an examination of foundatio... ...
# 1  This course offers an examination of foundatio... ...
# 2  This course offers an examination of foundatio... ...
# 3  The focus of this course, which is required fo... ...
# 4  The focus of this course, which is required fo... ...
#
#                              Textbooks and Resources  \
# 0  The following textbook and resource informatio...
# 1  The following textbook and resource informatio...
# 2  The following textbook and resource informatio...
# 3  The following textbook and resource informatio...
# 4                              No textbooks required
#
#                                    Time and Location        Type   courseID  \
# 0  Start and end times: \n12:30P - 1:45P\nTTh\n10...     Lecture  EPLS:3000
# 1  Start and end times: \n9:30A - 10:45A\nTTh\n10...     Lecture  EPLS:3000
# 2  Start and end times: \n12:30P - 1:45P\nTTh\n10...     Lecture  EPLS:3000
# 3  Start and end times: \n9:30A - 10:20A\nM\nW107...     Lecture  EPLS:4180
# 4  Start and end times: \n9:30A - 10:45A\nTTh\nN2...  Discussion  EPLS:4180
#
#                 college  department course_num  \
# 0  College of Education        EPLS       3000
# 1  College of Education        EPLS       3000
# 2  College of Education        EPLS       3000
# 3  College of Education        EPLS       4180
# 4  College of Education        EPLS       4180
#
#                                        name prereqs  hrs
# 0                  Foundations of Education      []  3.0
# 1                  Foundations of Education      []  3.0
# 2                  Foundations of Education      []  3.0
# 3  Human Relations for the Classroom Teachr      []  NaN
# 4  Human Relations for the Classroom Teachr      []  3.0
#
# [5 rows x 37 columns]

# %% [markdown]
# **Formatting**

# %%
# each course should have courseID
def format_courseID(course):
    split_name = course.split(':')[:2]
    return ":".join(split_name)


# department -> college
def format_college(x):
    if (x is not None):
        return x.split('\n')[0]
    else:
        return x
    
def format_dep(x):
    if (x is not None):
        return x.split(':')[0]
    else:
        return x

# course #
def format_course_num(x):
    if (x is not None):
        return x.split(':')[1]
    else:
        return x

# name
def format_name(x):
    human = x.split(' ', 1)[1].strip()
    return human.replace('\n', '').strip()

def format_hrs(x):
    if (x is None):
        return 0
    else:
        return x

# prereqs
def format_prereqs(prereq):
    if (prereq == None):
        return []
    elif (type(prereq) != str):
        prereq = str(prereq)
    elif prereq.startswith('None'):
        return []
    
    words = prereq.split()
    courses = [word.replace('(', '').replace(')', '') for word in words if ':' in word]
    
    return courses

# coreqs

# %%
# courseID
combined_classes['courseID'] = combined_classes['Course'].apply(format_courseID)

# college
combined_classes['college'] = combined_classes['Department'].apply(format_college)

# department
combined_classes['department'] = combined_classes['Course'].apply(format_dep)

# course num
combined_classes['course_num'] = combined_classes['Course'].apply(format_course_num)

# course name
combined_classes['name'] = combined_classes['Name'].apply(format_name)

# pre reqs
combined_classes['prereqs'] = combined_classes['Prerequisites'].apply(format_prereqs)

# hrs
combined_classes['hrs'] = combined_classes['Minimum Fee Hours'].apply(format_hrs)

# %%
output_df = combined_classes[['courseID', 'name', 'college', 'department', 'course_num', 'prereqs', 'hrs', 'Description', 'Link']]
output_df.head()
# Out:
#     courseID                                      name               college  \
# 0  EPLS:3000                  Foundations of Education  College of Education
# 1  EPLS:3000                  Foundations of Education  College of Education
# 2  EPLS:3000                  Foundations of Education  College of Education
# 3  EPLS:4180  Human Relations for the Classroom Teachr  College of Education
# 4  EPLS:4180  Human Relations for the Classroom Teachr  College of Education
#
#   department course_num prereqs  hrs  \
# 0       EPLS       3000      []  3.0
# 1       EPLS       3000      []  3.0
# 2       EPLS       3000      []  3.0
# 3       EPLS       4180      []  NaN
# 4       EPLS       4180      []  3.0
#
#                                          Description  \
# 0  This course offers an examination of foundatio...
# 1  This course offers an examination of foundatio...
# 2  This course offers an examination of foundatio...
# 3  The focus of this course, which is required fo...
# 4  The focus of this course, which is required fo...
#
#                                                 Link
# 0  https://myui.uiowa.edu/my-ui/courses/details.p...
# 1  https://myui.uiowa.edu/my-ui/courses/details.p...
# 2  https://myui.uiowa.edu/my-ui/courses/details.p...
# 3  https://myui.uiowa.edu/my-ui/courses/details.p...
# 4  https://myui.uiowa.edu/my-ui/courses/details.p...

# %%
# get rid of duplicates
print ("OG: {}".format(output_df.shape))

output_df.drop_duplicates(keep='last', inplace=True, subset=['courseID', 'name'])

print ("New: {}".format(output_df.shape))
# Out:
# OG: (7048, 9)
# New: (3482, 9)
# /home/user/.anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
output_df.head()
# Out:
#      courseID                                      name               college  \
# 2   EPLS:3000                  Foundations of Education  College of Education
# 6   EPLS:4180  Human Relations for the Classroom Teachr  College of Education
# 7   EPLS:4200      Diversity and Inclusion in Athletics  College of Education
# 9   EPLS:5090    Instr Coaching for Teaching Excellence  College of Education
# 10  EPLS:5100   Issues and Policies in Higher Education  College of Education
#
#    department course_num prereqs  hrs  \
# 2        EPLS       3000      []  3.0
# 6        EPLS       4180      []  3.0
# 7        EPLS       4200      []  3.0
# 9        EPLS       5090      []  3.0
# 10       EPLS       5100      []  3.0
#
#                                           Description  \
# 2   This course offers an examination of foundatio...
# 6   The focus of this course, which is required fo...
# 7   Certificate for Interscholastic Athletics/Acti...
# 9   This section is offered through Distance and O...
# 10  Current selected functions, issues, policies o...
#
#                                                  Link
# 2   https://myui.uiowa.edu/my-ui/courses/details.p...
# 6   https://myui.uiowa.edu/my-ui/courses/details.p...
# 7   https://myui.uiowa.edu/my-ui/courses/details.p...
# 9   https://myui.uiowa.edu/my-ui/courses/details.p...
# 10  https://myui.uiowa.edu/my-ui/courses/details.p...

# %%
base_f = '../data/formatted-courses.json'
output_df.to_json(base_f, orient='records')
